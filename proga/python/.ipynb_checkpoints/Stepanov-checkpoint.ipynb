# %%
- title: Контрольная работа (четверг)
- author: Артём Дегтярёв
- status: published
- date: 2023-11-02
- slug: 2023_lpr_test1_var2
- ipynb_url: download/2023_lpr_test1_var2.ipynb
# Out:
#   Cell In[142], line 4
#     - date: 2023-11-02
#                     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# ## Степанов
# Если этого не сделать, можно получить **-2 балла** к итоговой оценке за контрольную.

# %% [markdown]
# ## Оценивание.

# %% [markdown]
# Контрольная состоит из трех частей: основы, numpy, pandas. За них можно набрать максимум $23+12+23=58$ баллов. Это 25 задач, столько решать совсем не обязательно. На отл8 и выше требуется набрать не менее $8$ баллов за первую часть, не менее $7$ за вторую и не менее $8$ за третью. Оценка ставится по сумме баллов:
#
# - Отл10 39+ с условием выше
#
# - Отл9 31-38 с условием выше
#
# - Отл8 23-30 с условием выше
#
# - Хор7 20-22
#
# - Хор6 17-19
#
# - Хор5 14-16
#
# - Уд4 11-13
#
# - Уд3 8-10
#
# - Неуд2 5-7
#
# - Неуд1 0-4
#
# Решениями задач во всех радзелах должны быть коды, работающие корректно на любых адекватных задаче входных данных. В задачах третьей части (pandas) в ячейках должен быть написан код, результатом работы которого является число, серия или датафрейм.
#
# За списывание *решений задач* итоговая оценка может быть снижена на любое количество баллов на усмотрение проверяющих. Можно гуглить (с того же устройства, с которого решаете и отправляете контрольную) функции, методы и документацию, а также использовать свои jupyter ноутбуки.

# %% [markdown]
# # Основы, синтаксис

# %% [markdown]
# **Задача 1. (1 балл)** В Python операции с вещественными числами могут давать неожиданные результаты (например, 0.1 + 0.2 не будет в точности равняться 0.3). Требуется написать функцию eqv(a, b, c), которая принимает 3 числа. Числа вводятся с клавиатуры в одной строке через знак пробела. Сначала вводится число a, затем b и после c. Числа a и b складываются. Затем эта сумма сравнивается с числом "с" с определенной степенью точности. Точность равняется 0.01 % от большего из чисел a и b. Функция вернет True, если выполняется равенство, иначе False.
#
# Пример:
#
# *Входные данные:*
#
# `0.12 0.31 0.43`
#
# *Выходные данные:*
#
# `True`

# %%
def eqv(a, b, c):
    eps = 0.0001*max(a, b)
    if abs(a + b) < abs(c) + abs(eps) and abs(a + b) > abs(c) - abs(eps):
        return True
    else:
        return False

a, b, c = list(map(float, input().split()))
print(eqv(a, b, c))
# Out:
#  0.12 0.31 0.43
# True

# %% [markdown]
# **Задача 2. (1 балл)** Напишите **функцию** divider(a, b), которая принимает любые 2 числовых параметра. Задача функции: разделить a на b. Если в знаменателе введут ноль, то результат будет следующим: «В знаменателе не должно быть нулей». В противном случае выводится итог деления чисел, возведенный в куб.
#
# Решите задание без использования условия if, применяя свойства логических операторов.
#
# Примеры:
#
# `10 4` -> `15.625`
#
# `10 0` -> `В знаменателе не должно быть нулей`

# %%
def divider(a, b):
    try:
        return (a/b)**3
    except:
        return 'В знаменателе не должно быть нулей'

a, b = list(map(float, input().split()))
print(divider(a, b))
# Out:
#  10 4
# 15.625

# %% [markdown]
# **Задача 3. (1 балл)** С клавиатуры вводится строка, состоящая из слов, разделенных ровно одним пробелом. Определите, сколько в ней слов.
#
# Пример:
#
# *Входные данные:*
#
# `Hello world`
#
# *Выходные данные:*
#
# `2`

# %%
s = input().split()
print(len(s))
# Out:
#  Hello world
# 2

# %% [markdown]
# **Задача 4. (1 балл)** С клавиатуры вводится строка. Выбрать из этой строки каждый 3-й символ.
#
# Пример:
#
# *Входные данные:*
#
# `abc1de23fb5cabcbabc678`
#
# *Выходные данные:*
#
# `a12babc8`

# %%
s = input()
ans = []

for i in range(0, len(s)//3*3+1, 3):
    #print(i)
    ans.append(s[i])

print(''.join(ans))
# Out:
#  abc1de23fb5cabcbabc678
# a12babc8

# %% [markdown]
# **Задача 5. (1 балл)** С клавиатуры вводится список чисел. Возведите все его элементы в куб и выведите результат на экран. Пример:
#
# *Входные данные:*
#
# `1 -2 5 -10 3`
#
# *Выходные данные:*
#
# `1 -8 125 -1000 27`

# %%
l = list(map(float, input().split()))

print(*list(map(lambda x: x**3, l)))
# Out:
#  1 -2 5 -10 3
# 1.0 -8.0 125.0 -1000.0 27.0

# %% [markdown]
# **Задача 6. (2 балла)** С клавиатуры вводится список чисел **через запятую с пробелом**. Возведите все его элементы в куб **с помощью map** и выведите результат на экран. Пример:
#
# *Входные данные:*
#
# `1, -2, 5, -10, 3`
#
# *Выходные данные:*
#
# `1 -8 625 -1000 27`

# %%
l = list(map(float, input().split(', ')))

print(*list(map(lambda x: x**3, l)))
# Out:
#  1, -2, 5, -10, 3
# 1.0 -8.0 125.0 -1000.0 27.0

# %% [markdown]
# **Задача 7. (2 балла)** Создайте с помощью генератора списков (`list comprehension`) список из чисел от -100 до 100. С помощью функции `filter` удалите из него отрицательные числа, кратные 5. Затем с помощью функции `map` возведите оставшиеся числа в квадрат. Выведите результат на экран.

# %%
l = [x for x in range(-100, 101)]
l = list(filter(lambda x: not (x < 0 and x%5==0), l))
l = list(map(lambda x: x**2, l))

print(*l)
# Out:
# 9801 9604 9409 9216 8836 8649 8464 8281 7921 7744 7569 7396 7056 6889 6724 6561 6241 6084 5929 5776 5476 5329 5184 5041 4761 4624 4489 4356 4096 3969 3844 3721 3481 3364 3249 3136 2916 2809 2704 2601 2401 2304 2209 2116 1936 1849 1764 1681 1521 1444 1369 1296 1156 1089 1024 961 841 784 729 676 576 529 484 441 361 324 289 256 196 169 144 121 81 64 49 36 16 9 4 1 0 1 4 9 16 25 36 49 64 81 100 121 144 169 196 225 256 289 324 361 400 441 484 529 576 625 676 729 784 841 900 961 1024 1089 1156 1225 1296 1369 1444 1521 1600 1681 1764 1849 1936 2025 2116 2209 2304 2401 2500 2601 2704 2809 2916 3025 3136 3249 3364 3481 3600 3721 3844 3969 4096 4225 4356 4489 4624 4761 4900 5041 5184 5329 5476 5625 5776 5929 6084 6241 6400 6561 6724 6889 7056 7225 7396 7569 7744 7921 8100 8281 8464 8649 8836 9025 9216 9409 9604 9801 10000

# %% [markdown]
# **Задача 8. (2 балла)** Считайте в переменную строку из файла [`6.txt`](http://cs.mipt.ru/lpr2022/extra/task1/6.txt). Выведите символы этой строки в обратном порядке по одному, каждый с новой строки.
# Пример:
#
# *Входные данные:*
#
# `abc`
#
# *Выходные данные:*
#
# `c`
#
# `b`
#
# `a`

# %%
f = open('6.txt', 'r')
s = f.readline()

for i in s[::-1]: print(i)
# Out:
# h
# g
# f
# e
# f
# e
# d
# c
# d
# c
# b
# a

# %% [markdown]
# **Задача 9. (3 балла + 1 балл)** В шифре Цезаря каждый символ заменяется на другой символ, третий по счету в алфавите после данного, с цикличность. То есть символ A заменяется на D, символ B - на E, символ C - на F, ..., символ Z на C. Аналогично строчные буквы заменяются на строчные буквы. Все остальные символы не меняются.
#
# Дана строка, зашифруйте ее при помощи шифра Цезаря. Решение оформите в виде функции CaesarCipher(S, k), возвращающей новую строку.
# S — исходная строка, k — величина сдвига. Функцию нужно вызывать со значением k=3.
#
#
# Пример:
#
# *Входные данные:*
#
# `In a hole in the ground there lived a hobbit.`
#
# *Выходные данные:*
#
# `Lq d kroh lq wkh jurxqg wkhuh olyhg d kreelw.`

# %%
#'A' = 65
#'a' = 97

def CaesarCipher(S, k):
    newS = []
    for s in S:
        if ord(s) not in range(65, 91) and ord(s) not in range(97, 123): newS.append(s)
        #if s == ' ': newS.append(' ')
        #elif s == '.': newS.append('.')
        elif s.isupper(): newS.append(chr(65*(((ord(s) + k))//91) + (ord(s) + k)%91))
        else: newS.append(chr(97*(((ord(s) + k))//123) + (ord(s) + k)%123))
    return ''.join(newS)

S = input()

print(CaesarCipher(S, 3))
# Out:
#  In a hole in the ground there lived a hobbit.
# Lq d kroh lq wkh jurxqg wkhuh olyhg d kreelw.

# %% [markdown]
# **Задача 10. (4 балла)**
#
# В сети интернет каждому компьютеру присваивается четырехбайтовый код, который принято записывать в виде четырех чисел, каждое из которых может принимать значения от 0 до 255, разделенных точками. Вот примеры правильных IP-адресов:
#
# 127.0.0.0
#
# 192.168.0.1
#
# 255.0.255.255
#
# Пример:
#
# *Входные данные:*
#
# Программа получает на вход строку из произвольных символов длиной до 30 знаков.
#
# *Выходные данные:*
#
# Если эта строка является корректной записью IP-адреса, выведите YES, иначе выведите NO.

# %% [markdown]
# **Задача 11. (4 балла)**
#
# Дан список стран и городов каждой страны. Затем даны названия городов. Для каждого города укажите, в какой стране он находится.
#
# Пример:
#
# *Входные данные:*
#
# Программа получает на вход количество стран N. Далее идет N строк, каждая строка начинается с названия страны, затем идут названия городов этой страны. В следующей строке записано число M, далее идут M запросов — названия каких-то M городов, перечисленных выше.
#
# *Выходные данные:*
#
# Для каждого из запроса выведите название страны, в котором находится данный город.

# %% [markdown]
# # NumPy, визуализация
#
# Использование циклов `for` и `while` запрещено в этом разделе. При его использовании можно получить не более половины балла за задачу.

# %% [markdown]
# **Задача 1. (2 балла)** Найдите значение выражения $(a*b)(a + 2b) - 10b + 3a$, если $a = (2 \;\; 1)$, $b = (1 \;\; 3)$, $(a*b)$ - скалярное произведение векторов.

# %%
import numpy as np

# %%
a = np.array([2, 1])
b = np.array([1, 3])

ans = (a @ b)*(a + 2*b) - 10*b + 3*a
print(ans)
# Out:
# [16  8]

# %% [markdown]
# **Задача 2. (2 балла)** Найдите детерминант матрицы B = 2*A + E, где E - единичная матрица.

# %%
import numpy as np
A = np.array([[1, 2, 4],
              [3, 4, 1],
              [5, 6, 0]])

# %%
B = 2*A + np.identity(A.shape[0])

print(np.linalg.det(B))
# Out:
# -133.0

# %% [markdown]
# **Задача 3. (2 балла)** Найти косинус угла между векторами $a = \Big(\frac{\sqrt3}{2} \;\; -\frac{1}{2}\Big)$ и $b = (0 \;\; 1)$.

# %% [markdown]
# **Задача 4. (3 балла)** Решить систему уравнений
# $$
# \left\{
# \begin{array}{c}
# x+y+z=0 \\
# 4x+2y+3z=4 \\
# 15x+3y+5z=0
# \end{array}
# \right.
# $$

# %%
A = np.array([[1, 1, 1],
             [4, 2, 3],
             [15, 3, 5]])

y = np.array([0, 4, 0])
x = np.linalg.inv(A) @ y

print(x)
# Out:
# [-1. -5.  6.]

# %% [markdown]
# **Задача 5 (3 балла).** Построить график функции $(x + 1) \cdot \frac{1 + \cos x}{\sin{x}}$ для $x$ в интервале от -10 до 10.

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10)
y = (x+1)*(1 + np.cos(x))/np.sin(x)

plt.plot(x, y)

# %% [markdown]
# # Pandas
# Для выполнения заданий **загрузите файл** [worldcities_short.csv](http://cs.mipt.ru/lpr2022/extra/task1/worldcities_short.csv)!
# Во всех задачах ответом должно быть либо одно число, либо датафрейм, полученное с помощью команд pandas (например, если число-ответ видно в датафрейме, его нужно не вывести вручную, а вытащить с помощью команд pandas).
#
# Использование циклов `for` и `while` запрещено в этом разделе. При его использовании можно получить не более половины балла за задачу.

# %% [markdown]
# **Задача 1. (1 балл)** Выведите 10 случайно выбранных строк таблицы. Сколько различных стран представлено в таблице?

# %%
import pandas as pd
df = pd.read_csv('worldcities_short.csv')

# %%
import random

df.sample(10)
# Out:
#        Unnamed: 0                    city      lat       lng        country  \
# 749           749                Monrovia   6.3133  -10.8014        Liberia
# 43892       43892            Halfmoon Bay -46.9000  168.1333    New Zealand
# 36807       36807                Timahdit  33.2369   -5.0600        Morocco
# 21377       21377                Malargüe -35.4750  -69.5833      Argentina
# 36036       36036          Sajószentpéter  48.2169   20.7183        Hungary
# 42199       42199           Philippeville  50.2000    4.5500        Belgium
# 35193       35193                El Ayote  12.4972  -84.8181      Nicaragua
# 10920       10920             West Athens  33.9235 -118.3033  United States
# 17554       17554  São Francisco do Conde -12.6278  -38.6800         Brazil
# 2284         2284           Niagara Falls  43.0600  -79.1067         Canada
#
#        capital  population
# 749    primary   1021762.0
# 43892      NaN       300.0
# 36807      NaN     10945.0
# ...

# %%
print(len(df['country'].unique()))
# Out:
# 241

# %% [markdown]
# **Задача 2. (1 балл)** Какая средняя численность населения в представленных странах?

# %%
df1 = df[['country', 'population']].groupby(by = 'country').mean()
df1
# Out:
#                       population
# country
# Afghanistan        154134.582090
# Albania             41797.736842
# Algeria             86425.939759
# American Samoa      12576.000000
# Andorra             11095.285714
# ...                          ...
# Wallis and Futuna            NaN
# West Bank           47672.777778
# Yemen              157821.363636
# Zambia             153344.658537
# Zimbabwe           127659.675676
#
# [241 rows x 1 columns]

# %%
print(np.mean(df1['population']))
# Out:
# 126128.93544823812

# %% [markdown]
# **Задача 3. (2 балла)** Вычислите среднюю численнотсь населения среди стран города которых имеют координаты: широта (lat) от 10 до 60 и  долгота (lng) от 50 до 100?

# %%
#решаем в презумпции что ХОТЯ БЫ ОДИН город лежит в нужных координатах чтобы страна походила

df1 = df[df['lat'] > 10]
df1 = df1[df1['lat'] < 60]
df1 = df1[df1['lng'] > 50]
df1 = df1[df1['lng'] < 100]

countries = df1['country'].unique()
#print(countries)
df2 = df[df['country'].isin(countries)]
df2 = df2[['country', 'population']].groupby('country').sum()
df2
#len(countries)
#len(df2)
# Out:
#                         population
# country
# Afghanistan           1.032702e+07
# Azerbaijan            5.767590e+06
# Bahrain               7.312690e+05
# Bangladesh            4.350312e+07
# Bhutan                2.077280e+05
# China                 1.420420e+09
# India                 4.371702e+08
# Iran                  6.483275e+07
# Kazakhstan            1.179485e+07
# Kyrgyzstan            3.139850e+06
# Mongolia              2.240903e+06
# Myanmar               1.908134e+07
# Nepal                 4.252020e+06
# Oman                  3.834268e+06
# Pakistan              6.421463e+07
# Qatar                 2.353614e+06
# Russia                1.076237e+08
# Saudi Arabia          2.499083e+07
# Somalia               1.671180e+07
# Tajikistan            4.374883e+06
# Thailand              2.842796e+07
# Turkmenistan          2.697719e+06
# United Arab Emirates  7.689518e+06
# Uzbekistan            1.156947e+07
# Yemen                 6.944140e+06

# %%
print(np.mean(df2['population']))
# Out:
# 92196049.0

# %% [markdown]
# **Задача 4. (2 балла)** Отсортируйте города в порядке увеличения длины названия города.

# %%
lens = list(map(lambda x: len(x), df['city']))

df1 = df
df1['lens'] = lens
df1 = df.sort_values('lens')
df1 = df.drop('lens', axis = 1)
df1
# Out:
#        Unnamed: 0         city      lat       lng    country  capital  \
# 0               0        Tokyo  35.6897  139.6922      Japan  primary
# 1               1      Jakarta  -6.1750  106.8275  Indonesia  primary
# 2               2        Delhi  28.6100   77.2300      India    admin
# 3               3    Guangzhou  23.1300  113.2600      China    admin
# 4               4       Mumbai  19.0761   72.8775      India    admin
# ...           ...          ...      ...       ...        ...      ...
# 44686       44686        Numto  63.6667   71.3333     Russia      NaN
# 44687       44687         Nord  81.7166  -17.8000  Greenland      NaN
# 44688       44688  Timmiarmiut  62.5333  -42.2167  Greenland      NaN
# 44689       44689   San Rafael -16.7795  -60.6799    Bolivia      NaN
# 44690       44690      Nordvik  74.0165  111.5100     Russia      NaN
#
#        population
# 0      37732000.0
# 1      33756000.0
# 2      32226000.0
# 3      26940000.0
# 4      24973000.0
# ...

# %% [markdown]
# **Задача 5. (2 балла)** Сгруппируйте данные по типу столицы и рассчитайте среднюю численность населения, число городов.

# %% [markdown]
# **Задача 6. (4 балла)** Выполните категоризацию (разделите на 4 группы, границы определите самостоятельно) численности населения (примените метод .apply() и самописную функцию). Сгруппируйте страны по этим категориям и подсчитайте число записей в каждой категории.

# %% [markdown]
# **Задача 7. (1 балла)** Какая самая встречающаяся в таблице страна?

# %%
from collections import Counter

most_common = Counter(df['country']).most_common(1)[0][0]
print(most_common)
# Out:
# India

# %% [markdown]
# **Задача 8. (3 балла)** Вычислите среднюю численость населения по городам страны которая встречается в таблице чаще всего.

# %%
df1 = df[df['country'] == most_common]
df1
# Out:
#        Unnamed: 0           city      lat      lng country capital  \
# 2               2          Delhi  28.6100  77.2300   India   admin
# 4               4         Mumbai  19.0761  72.8775   India   admin
# 14             14        Kolkāta  22.5675  88.3700   India   admin
# 22             22      Bangalore  12.9789  77.5917   India   admin
# 29             29        Chennai  13.0825  80.2750   India   admin
# ...           ...            ...      ...      ...     ...     ...
# 44407       44407         Segaon  21.8585  75.3293   India     NaN
# 44410       44410       Sobhāpur  22.7737  78.2638   India     NaN
# 44421       44421    Poninguinim  14.9679  74.0865   India     NaN
# 44430       44430  Chāpalamadugu  16.0730  79.3775   India     NaN
# 44431       44431       Munnelli  14.9200  78.9546   India     NaN
#
#        population  lens
# 2      32226000.0     5
# 4      24973000.0     6
# 14     18502000.0     7
# 22     15386000.0     9
# 29     12395000.0     7
# ...

# %%
print(df1['population'].mean())
# Out:
# 73896.25185936443

# %% [markdown]
# **Задача 9. (3 балла)** Сгруппируйте записи таблицы по странам и создайте столбец в котором будет число городов, представленных в данных. Используя left join присоедините к исходной таблице данные по числу городов.

# %% [markdown]
# **Задача 10. (4 балла)** Найдите страны для которых название города начинается с 'T' и заканчивается на 'o'. Здесь потребуется применить регулярные выражения и метод .apply().
